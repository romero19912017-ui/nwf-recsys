# %% [markdown]
# # MovieLens 100k: Recommendations with NWF
#
# MatrixFactorEncoder, item Field, HR@k, cold-start simulation.

# %%
# %run ../examples/movielens_100k.py

# %% [markdown]
# Or: `python examples/movielens_100k.py --save results/recsys.png`
